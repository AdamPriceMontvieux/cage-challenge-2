# %%
from gym.spaces import Box
import numpy as np

from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.models.tf.tf_modelv2 import TFModelV2
from ray.rllib.models.tf.fcnet import FullyConnectedNetwork
from ray.rllib.models.torch.misc import SlimFC
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.torch.fcnet import FullyConnectedNetwork as TorchFC
from ray.rllib.utils.annotations import override
from ray.rllib.utils.framework import try_import_tf, try_import_torch
from ray.rllib.agents.dqn.dqn import DQNTrainer
from ray.rllib.agents.dqn import dqn


tf1, tf, tfv = try_import_tf()
torch, nn = try_import_torch()

# %%
class SupervisorModel(TFModelV2):
    
    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        super(SupervisorModel, self).__init__(
            obs_space, action_space, num_outputs, model_config, name
        )
        # Base of the model for PPO agents
        self.model = FullyConnectedNetwork(
            obs_space, action_space, num_outputs, model_config, name
        )
  
        # Upper DQN for action masking
        #obs = tf.keras.layers.Input(shape=(obs_space.shape[0],), name="obs")
        #hidden_1 = tf.keras.layers.Dense(512, activation=tf.nn.tanh, name="hidden_1")(obs)
        #hidden_2 = tf.keras.layers.Dense(512, activation=tf.nn.tanh, name="hidden_2")(hidden_1)
        #q_values = tf.keras.layers.Dense(action_space.n, activation=None, name="q_values")(hidden_2)
        #self.supervisor_q_vals = tf.keras.Model(inputs=[obs], outputs=q_values)
    
        dqn_config = dqn.DEFAULT_CONFIG.copy()
        dqn_config.update({"num_gpus": 0,"num_workers":0,
                            "framework": "tf2",
                            "horizon": 100,
                            'train_batch_size': 32,
                            'double_q': True,
                            'dueling': True,
                           'hiddens': [512],
                            "model": {
                                "fcnet_hiddens": [512],
                                "fcnet_activation": "relu",
                           }}) 
        self.supervisor = DQNTrainer(config=dqn_config,env="CybORG")
        self.supervisor.restore("supervisor/checkpoint_000639/checkpoint-639")

    @override(ModelV2)
    def forward(self, input_dict, state, seq_lens):
    
        action_logits = self.model.forward(input_dict, state, seq_lens)[0]
       # if input_dict[SampleBatch.CUR_OBS].shape[0] > 1:

       #     return action_logits, state
        #q_vals = self.supervisor_q_vals(input_dict[SampleBatch.CUR_OBS])
        q_vals = self.supervisor.compute_single_action(input_dict[SampleBatch.CUR_OBS][0], full_fetch=True, explore=False, training=False)[2]['q_values']
        max_q_vals = tf.math.top_k(q_vals, k=2, sorted=False, name=None)
        indices = tf.cast(max_q_vals.indices, dtype=tf.int32).numpy()
       # action_mask = np.zeros(tf.shape(action_logits).numpy(), dtype=int)
       # action_mask[:,indices] = 1
        # Expand the model output to [BATCH, 1, EMBED_SIZE]. Note that the
        # avail actions tensor is of shape [BATCH, MAX_ACTIONS, EMBED_SIZE].
       # intent_vector = tf.expand_dims(action_embed, 1)
        #action_logits = tf.expand_dims(action_logits, 1)
       # print(action_logits)
        # Batch dot product => shape of logits is [BATCH, MAX_ACTIONS].
      #  action_logits = tf.cast(tf.reduce_sum(action_mask * action_logits, axis=1), dtype=tf.float32)
       # print(action_logits)
        min_mask = np.ones(tf.shape(action_logits).numpy()) * -1
        min_mask[:,indices] = 0
       # print(action_logits)
        action_logits = action_logits + min_mask
        #print(action_logits)
       # print(action_logits)
        return action_logits, state
        
        #action_mask = np.zeros(tf.shape(q_vals).numpy(), dtype=bool)
       # action_mask[indices] = True
       # masked_logits = action_logits[0] * action_mask
       # return tf.expand_dims(masked_logits, axis=0), state
    
    @override(ModelV2)
    def value_function(self):
        return self.model.value_function()

    def q_value_function(self, obs, opponent_obs, opponent_actions):
        return tf.reshape(self.supervisor_q_vals(obs),[-1])

# %% [markdown]
#  425 	r_mean: -27.8 	r_max: -11.8 	r_min: -147.7
# /Supervisor/checkpoint_000425/checkpoint-425

# %%
from ray.rllib.agents.ppo.ppo_tf_policy import PPOTFPolicy
from ray.rllib.policy.sample_batch import SampleBatch

class SupervisorPolicy(PPOTFPolicy):
    def __init__(self, observation_space, action_space, config):
        PPOTFPolicy.__init__(self, observation_space, action_space, config)

    @override(PPOTFPolicy)
    def loss(self, model, dist_class, train_batch):
        loss = super().loss
        
        #q_val_s = model.supervisor_q_vals({train_batch[SampleBatch.CUR_OBS]})[0]
        #q_val_ns = model.supervisor_q_vals({train_batch[SampleBatch.NEXT_OBS]})[0]
        
        #action_selection = tf.cast(train_batch[SampleBatch.ACTIONS], dtype=tf.int32)   
        #one_hot_selection = tf.one_hot(action_selection, 1)
        #selected_q = tf.reduce_sum(q_val_s * one_hot_selection, 1)
        #dones = tf.cast(train_batch[SampleBatch.DONES], tf.float32)
        
        #one_hot_max = tf.one_hot(tf.argmax(q_val_ns, 1), 1)
        #ns_max_q = tf.reduce_sum(q_val_ns * one_hot_max, 1)
        #ns_max_q = (1.0 - dones) * ns_max_q
        #Calculate TD error and convert to huber loss
        #target_q = (train_batch[SampleBatch.REWARDS] + policy.config["gamma"] * ns_max_q)
        #td_error = selected_q - tf.stop_gradient(target_q)
        #DQN_Loss = tf.reduce_sum(huber_loss(td_error)) 
        
        return loss #+ DQN_Loss

# %%
from ray.rllib.agents.ppo.ppo import PPOTrainer
class SVTrainer(PPOTrainer):
    def get_default_policy_class(self, config):
        return SupervisorPolicy

# %%
from CybORG import CybORG
from CybORG.Agents import B_lineAgent, SleepAgent, GreenAgent
from CybORG.Agents.SimpleAgents.BaseAgent import BaseAgent
from CybORG.Agents.SimpleAgents.BlueReactAgent import BlueReactRemoveAgent
from CybORG.Agents.SimpleAgents.Meander import RedMeanderAgent
from CybORG.Agents.Wrappers.EnumActionWrapper import EnumActionWrapper
from CybORG.Agents.Wrappers.FixedFlatWrapper import FixedFlatWrapper
from CybORG.Agents.Wrappers.OpenAIGymWrapper import OpenAIGymWrapper
from CybORG.Agents.Wrappers.ReduceActionSpaceWrapper import ReduceActionSpaceWrapper
from CybORG.Agents.Wrappers import ChallengeWrapper
from ray.rllib.models import ModelCatalog
from ray.tune.registry import register_env
from ray.rllib.agents import ppo
import inspect
from CybORG.Agents.Wrappers.rllib_wrapper import RLlibWrapper

def env_creator(env_config: dict):
    path = str(inspect.getfile(CybORG))
    path = path[:-10] + '/Shared/Scenarios/Scenario2.yaml'
    agents = {"Red": B_lineAgent, "Green": GreenAgent}
    cyborg = CybORG(scenario_file=path, environment='sim', agents=agents)
    env = RLlibWrapper(env=cyborg, agent_name="Blue", max_steps=100)
    return env

def print_results(results_dict):
    train_iter = results_dict["training_iteration"]
    r_mean = results_dict["episode_reward_mean"]
    r_max = results_dict["episode_reward_max"]
    r_min = results_dict["episode_reward_min"]
    print(f"{train_iter:4d} \tr_mean: {r_mean:.1f} \tr_max: {r_max:.1f} \tr_min: {r_min: .1f}")

import subprocess
import json
import os

batch_size = 4000
# Set up CybORG
register_env(name="CybORG", env_creator=env_creator)
config = ppo.DEFAULT_CONFIG.copy()

ModelCatalog.register_custom_model("sv_model", SupervisorModel)

from shutil import make_archive
allrewards = []

config.update({"num_gpus": 1,"num_workers": 20,
                # Also, use "framework: tf2" for tfe eager execution.
                "framework": "tf2",
                "train_batch_size": batch_size,
                "horizon": 100,
                "gamma": 0.9,
                "model": {
                    "custom_model": "sv_model",
                    "fcnet_hiddens": [512, 512],
                    "fcnet_activation": "relu",
                },

                }) 
trainer = SVTrainer(config=config, env="CybORG")

reward = []
novel_obs = []
novel_actions = []
for i in range(200):
    results_dict = trainer.train()
    print_results(results_dict)
# Out:
# (RolloutWorker pid=23288) 2022-08-02 15:41:43,347	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23307) 2022-08-02 15:41:43,493	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23308) 2022-08-02 15:41:43,531	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23302) 2022-08-02 15:41:43,705	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23315) 2022-08-02 15:41:43,712	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23323) 2022-08-02 15:41:43,716	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23320) 2022-08-02 15:41:43,700	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23289) 2022-08-02 15:41:43,827	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23317) 2022-08-02 15:41:43,855	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23304) 2022-08-02 15:41:43,957	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23311) 2022-08-02 15:41:44,164	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23324) 2022-08-02 15:41:44,326	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23312) 2022-08-02 15:41:44,297	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23308) 2022-08-02 15:41:44,540	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23307) 2022-08-02 15:41:44,555	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23294) 2022-08-02 15:41:44,575	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23318) 2022-08-02 15:41:44,563	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23288) 2022-08-02 15:41:44,824	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23308) 2022-08-02 15:41:44,841	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23302) 2022-08-02 15:41:44,757	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23315) 2022-08-02 15:41:44,770	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23323) 2022-08-02 15:41:44,768	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23320) 2022-08-02 15:41:44,782	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23308) 2022-08-02 15:41:44,876	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23308) 2022-08-02 15:41:44,876	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23307) 2022-08-02 15:41:44,868	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23307) 2022-08-02 15:41:44,902	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23307) 2022-08-02 15:41:44,902	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23289) 2022-08-02 15:41:44,962	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23317) 2022-08-02 15:41:44,913	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23302) 2022-08-02 15:41:45,082	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23302) 2022-08-02 15:41:45,118	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23302) 2022-08-02 15:41:45,118	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23315) 2022-08-02 15:41:45,105	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23315) 2022-08-02 15:41:45,141	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23315) 2022-08-02 15:41:45,141	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23323) 2022-08-02 15:41:45,094	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23323) 2022-08-02 15:41:45,128	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23323) 2022-08-02 15:41:45,128	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23320) 2022-08-02 15:41:45,104	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23320) 2022-08-02 15:41:45,140	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23320) 2022-08-02 15:41:45,140	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23290) 2022-08-02 15:41:45,183	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23300) 2022-08-02 15:41:45,139	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23288) 2022-08-02 15:41:45,280	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23317) 2022-08-02 15:41:45,281	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23311) 2022-08-02 15:41:45,258	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23288) 2022-08-02 15:41:45,325	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23288) 2022-08-02 15:41:45,326	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23289) 2022-08-02 15:41:45,408	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=23317) 2022-08-02 15:41:45,314	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=23317) 2022-08-02 15:41:45,314	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 639, '_timesteps_total': None, '_time_total': 2267.168159008026, '_episodes_total': 6640}
# (RolloutWorker pid=23296) 2022-08-02 15:41:45,393	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23289) 2022-08-02 15:41:45,457	INFO trainable.py:588 -- Restored on 172.28.0.2 from checkpoint: /Supervisor/checkpoint_000639/checkpoint-639
# (RolloutWorker pid=