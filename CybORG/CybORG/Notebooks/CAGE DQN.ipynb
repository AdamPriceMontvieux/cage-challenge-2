# %% [markdown]
# Create the trainer

# %%
import inspect
import time
from statistics import mean, stdev
from CybORG import CybORG
from CybORG.Agents import B_lineAgent, SleepAgent, GreenAgent
from CybORG.Agents.SimpleAgents.BaseAgent import BaseAgent
from CybORG.Agents.SimpleAgents.BlueReactAgent import BlueReactRemoveAgent
from CybORG.Agents.SimpleAgents.Meander import RedMeanderAgent
from CybORG.Agents.Wrappers.EnumActionWrapper import EnumActionWrapper
from CybORG.Agents.Wrappers.FixedFlatWrapper import FixedFlatWrapper
from CybORG.Agents.Wrappers.OpenAIGymWrapper import OpenAIGymWrapper
from CybORG.Agents.Wrappers.ReduceActionSpaceWrapper import ReduceActionSpaceWrapper
from CybORG.Agents.Wrappers import ChallengeWrapper
import os
from ray.rllib.agents.ppo import PPOTrainer
from ray.rllib.agents import ppo
from ray.tune.registry import register_env
from CybORG.Agents.Wrappers.rllib_wrapper import RLlibWrapper
import warnings
import numpy as np
import random
import ray
from collections import deque
warnings.filterwarnings('ignore')

# %%
MAX_EPS = 50
agent_name = 'Blue'

def wrap(env):
    return RLlibWrapper(agent_name="Blue", env=env)


def evaluate(steps):
    path = str(inspect.getfile(CybORG))
    path = path[:-10] + '/Shared/Scenarios/Scenario2.yaml'

    #print(f'using CybORG v{cyborg_version}, {scenario}\n')
    for num_steps in steps:
        for red_agent in [B_lineAgent, RedMeanderAgent, SleepAgent]:

            cyborg = CybORG(path, 'sim', agents={'Red': red_agent})
            wrapped_cyborg = wrap(cyborg)

            observation = wrapped_cyborg.reset()
            # observation = cyborg.reset().observation

            action_space = wrapped_cyborg.get_action_space(agent_name)
            # action_space = cyborg.get_action_space(agent_name)
            total_reward = []
            actions = []
            for i in range(MAX_EPS):
                r = []
                a = []
                # cyborg.env.env.tracker.render()
                for j in range(num_steps):
                    action = trainer.compute_single_action(observation)
                    #action = agent.get_action(observation, action_space)
                    observation, rew, done, info = wrapped_cyborg.step(action)
                    # result = cyborg.step(agent_name, action)
                    r.append(rew)
                    # r.append(result.reward)
                    a.append((str(cyborg.get_last_action('Blue')), str(cyborg.get_last_action('Red'))))
                total_reward.append(sum(r))
                actions.append(a)
                # observation = cyborg.reset().observation
                observation = wrapped_cyborg.reset()
            print(f'Average reward for red agent {red_agent.__name__} and steps {num_steps} is: {mean(total_reward):.1f} with a standard deviation of {stdev(total_reward):.1f}')

# %%
from ray.rllib.offline.json_writer import JsonWriter
from ray.rllib.offline.dataset_writer import DatasetWriter
from ray.rllib.offline.io_context import IOContext
from datetime import datetime
import shutil
import inspect
from ray.tune.registry import register_env

def env_creator(env_config: dict):
    path = str(inspect.getfile(CybORG))
    path = path[:-10] + '/Shared/Scenarios/Scenario2.yaml'
    agents = {"Red": B_lineAgent, "Green": GreenAgent}
    cyborg = CybORG(scenario_file=path, environment='sim', agents=agents)
    env = RLlibWrapper(env=cyborg, agent_name="Blue", max_steps=100)
    return env

def print_results(results_dict):
    train_iter = results_dict["training_iteration"]
    r_mean = results_dict["episode_reward_mean"]
    r_max = results_dict["episode_reward_max"]
    r_min = results_dict["episode_reward_min"]
    print(f"{train_iter:4d} \tr_mean: {r_mean:.1f} \tr_max: {r_max:.1f} \tr_min: {r_min: .1f}")
    
register_env(name="CybORG", env_creator=env_creator)

# %%
from ray.rllib.agents.dqn.dqn import DQNTrainer
from ray.rllib.agents.dqn import dqn
import ray

all_rewards = []


dqn_config = dqn.DEFAULT_CONFIG.copy()
dqn_config.update({"num_gpus": 1,"num_workers":20,
                    "framework": "tf2",
                    "horizon": 100,
                    'lr': 0.00025,
                    'train_batch_size': 32,
                    'double_q': True,
                    "gamma": 0.95,
                    'dueling': True,
                    'hiddens': [512],
                    "model": {
                        "fcnet_hiddens": [512],
                        "fcnet_activation": "relu",
                    },
                    #"exploration_config": {
                    #    "type": "Curiosity",
                    #    "sub_exploration": "EpsilonGreedy",
                    #    "inverse_net_hiddens": [512],  
                    #    "inverse_net_activation": "relu",  
                    #    "forward_net_hiddens": [512],  
                    #    "forward_net_activation": "relu", }
                  }) 
rewards = []
trainer = DQNTrainer(config=dqn_config, env="CybORG")

m = -60
for i in range(int(500)):
    results_dict=trainer.train()
    print_results(results_dict)
    rewards.append(results_dict["episode_reward_mean"])
    if m < results_dict["episode_reward_mean"]:
        print(trainer.save("/Supervisor"))
        m = results_dict["episode_reward_mean"]
        
all_rewards.append(rewards)
trainer.save("/Supervisor")
# Out:
# (RolloutWorker pid=13994) 2022-08-02 11:17:34,495	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14023) 2022-08-02 11:17:34,823	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14028) 2022-08-02 11:17:34,838	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14019) 2022-08-02 11:17:34,852	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14017) 2022-08-02 11:17:34,873	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14013) 2022-08-02 11:17:34,883	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=13997) 2022-08-02 11:17:35,008	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14021) 2022-08-02 11:17:35,195	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14001) 2022-08-02 11:17:35,266	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14009) 2022-08-02 11:17:35,330	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=13991) 2022-08-02 11:17:35,524	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14015) 2022-08-02 11:17:35,620	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=13992) 2022-08-02 11:17:35,738	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14025) 2022-08-02 11:17:35,704	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=13999) 2022-08-02 11:17:35,806	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=13993) 2022-08-02 11:17:35,890	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14003) 2022-08-02 11:17:35,926	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14006) 2022-08-02 11:17:35,941	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=14010) 2022-08-02 11:17:36,137	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# 2022-08-02 11:17:36,216	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=14005) 2022-08-02 11:17:36,598	WARNING env.py:135 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
#    1 	r_mean: nan 	r_max: nan 	r_min:  nan
#    2 	r_mean: -689.2 	r_max: -128.8 	r_min: -1151.7
#    3 	r_mean: -689.2 	r_max: -128.8 	r_min: -1151.7
#    4 	r_mean: -806.5 	r_max: -128.8 	r_min: -1151.7
#    5 	r_mean: -806.5 	r_max: -128.8 	r_min: -1151.7
#    6 	r_mean: -814.6 	r_max: -128.8 	r_min: -1152.7
#    7 	r_mean: -814.6 	r_max: -128.8 	r_min: -1152.7
#    8 	r_mean: -860.8 	r_max: -128.8 	r_min: -1184.8
#    9 	r_mean: -860.8 	r_max: -128.8 	r_min: -1184.8
#   10 	r_mean: -780.3 	r_max: -78.8 	r_min: -1184.8
#   11 	r_mean: -780.3 	r_max: -78.8 	r_min: -1184.8
#   12 	r_mean: -700.1 	r_max: -78.8 	r_min: -1184.8
#   13 	r_mean: -700.1 	r_max: -78.8 	r_min: -1184.8
#   14 	r_mean: -573.6 	r_max: -78.8 	r_min: -1184.8
#   15 	r_mean: -573.6 	r_max: -78.8 	r_min: -1184.8
#   16 	r_mean: -465.2 	r_max: -78.8 	r_min: -1184.8
#   17 	r_mean: -465.2 	r_max: -78.8 	r_min: -1184.8
#   18 	r_mean: -316.7 	r_max: -78.8 	r_min: -839.3
#   19 	r_mean: -316.7 	r_max: -78.8 	r_min: -839.3
#   20 	r_mean: -273.5 	r_max: -204.8 	r_min: -294.8
#   21 	r_mean: -273.5 	r_max: -204.8 	r_min: -294.8
#   22 	r_mean: -263.5 	r_max: -181.7 	r_min: -294.8
#   23 	r_mean: -263.5 	r_max: -181.7 	r_min: -294.8
#   24 	r_mean: -254.6 	r_max: -181.7 	r_min: -294.8
#   25 	r_mean: -244.9 	r_max: -181.7 	r_min: -280.8
#   26 	r_mean: -244.9 	r_max: -181.7 	r_min: -280.8
#   27 	r_mean: -236.1 	r_max: -167.7 	r_min: -263.8
#   28 	r_mean: -236.1 	r_max: -167.7 	r_min: -263.8
#   29 	r_mean: -227.4 	r_max: -167.7 	r_min: -258.7
#   30 	r_mean: -227.4 	r_max: -167.7 	r_min: -258.7
#   31 	r_mean: -214.7 	r_max: -152.7 	r_min: -254.8
#   32 	r_mean: -214.7 	r_max: -152.7 	r_min: -254.8
#   33 	r_mean: -204.2 	r_max: -90.7 	r_min: -270.8
#   34 	r_mean: -204.2 	r_max: -90.7 	r_min: -270.8
#   35 	r_mean: -186.6 	r_max: -90.7 	r_min: -270.8
#   36 	r_mean: -186.6 	r_max: -90.7 	r_min: -270.8
#   37 	r_mean: -177.4 	r_max: -81.8 	r_min: -270.8
#   38 	r_mean: -177.4 	r_max: -81.8 	r_min: -270.8
#   39 	r_mean: -168.3 	r_max: -81.8 	r_min: -270.8
#   40 	r_mean: -168.3 	r_max: -81.8 	r_min: -270.8
#   41 	r_mean: -162.2 	r_max: -81.8 	r_min: -270.8
#   42 	r_mean: -162.2 	r_max: -81.8 	r_min: -270.8
#   43 	r_mean: -163.4 	r_max: -81.8 	r_min: -243.7
#   44 	r_mean: -163.4 	r_max: -81.8 	r_min: -243.7
#   45 	r_mean: -173.9 	r_max: -81.8 	r_min: -242.8
#   46 	r_mean: -173.9 	r_max: -81.8 	r_min: -242.8
#   47 	r_mean: -181.0 	r_max: -91.8 	r_min: -242.8
#   48 	r_mean: -181.0 	r_max: -91.8 	r_min: -242.8
#   49 	r_mean: -183.9 	r_max: -91.8 	r_min: -209.8
#   50 	r_mean: -186.5 	r_max: -123.7 	r_min: -209.8
#   51 	r_mean: -186.5 	r_max: -123.7 	r_min: -209.8
#   52 	r_mean: -171.0 	r_max: -75.1 	r_min: -209.7
#   53 	r_mean: -171.0 	r_max: -75.1 	r_min: -209.7
#   54 	r_mean: -155.1 	r_max: -75.1 	r_min: -210.8
#   55 	r_mean: -155.1 	r_max: -75.1 	r_min: -210.8
#   56 	r_mean: -147.8 	r_max: -75.1 	r_min: -289.8
#   57 	r_mean: -147.8 	r_max: -75.1 	r_min: -289.8
#   58 	r_mean: -151.0 	r_max: -75.1 	r_min: -291.8
#   59 	r_mean: -151.0 	r_max: -75.1 	r_min: -291.8
#   60 	r_mean: -171.3 	r_max: -75.1 	r_min: -1122.8
#   61 	r_mean: -171.3 	r_max: -75.1 	r_min: -1122.8
#   62 	r_mean: -178.1 	r_max: -72.7 	r_min: -1122.8
#   63 	r_mean: -178.1 	r_max: -72.7 	r_min: -1122.8
#   64 	r_mean: -179.0 	r_max: -58.8 	r_min: -1122.8
#   65 	r_mean: -179.0 	r_max: -58.8 	r_min: -1122.8
#   66 	r_mean: -168.8 	r_max: -55.6 	r_min: -1122.8
#   67 	r_mean: -168.8 	r_max: -55.6 	r_min: -1122.8
#   68 	r_mean: -154.3 	r_max: -55.6 	r_min: -1122.8
#   69 	r_mean: -154.3 	r_max: -55.6 	r_min: -1122.8
#   70 	r_mean: -129.1 	r_max: -55.6 	r_min: -238.8
#   71 	r_mean: -129.1 	r_max: -55.6 	r_min: -238.8
#   72 	r_mean: -117.0 	r_max: -55.6 	r_min: -236.8
#   73 	r_mean: -117.0 	r_max: -55.6 	r_min: -236.8
#   74 	r_mean: -111.4 	r_max: -55.6 	r_min: -228.7
#   75 	r_mean: -114.5 	r_max: -56.8 	r_min: -238.7
#   76 	r_mean: -114.5 	r_max: -56.8 	r_min: -238.7
#   77 	r_mean: -115.6 	r_max: -56.8 	r_min: -238.8
#   78 	r_mean: -115.6 	r_max: -56.8 	r_min: -238.8
#   79 	r_mean: -113.6 	r_max: -56.8 	r_min: -238.8
#   80 	r_mean: -113.6 	r_max: -56.8 	r_min: -238.8
#   81 	r_mean: -119.1 	r_max: -56.8 	r_min: -238.8
#   82 	r_mean: -119.1 	r_max: -56.8 	r_min: -238.8
#   83 	r_mean: -120.7 	r_max: -56.8 	r_min: -238.8
#   84 	r_mean: -120.7 	r_max: -56.8 	r_min: -238.8
#   85 	r_mean: -120.4 	r_max: -56.7 	r_min: -238.8
#   86 	r_mean: -120.4 	r_max: -56.7 	r_min: -238.8
#   87 	r_mean: -125.3 	r_max: -17.8 	r_min: -240.8
#   88 	r_mean: -125.3 	r_max: -17.8 	r_min: -240.8
#   89 	r_mean: -131.5 	r_max: -17.8 	r_min: -242.8
#   90 	r_mean: -131.5 	r_max: -17.8 	r_min: -242.8
#   91 	r_mean: -133.8 	r_max: -17.8 	r_min: -246.7
#   92 	r_mean: -133.8 	r_max: -17.8 	r_min: -246.7
#   93 	r_mean: -138.6 	r_max: -17.8 	r_min: -270.8
#   94 	r_mean: -138.6 	r_max: -17.8 	r_min: -270.8
#   95 	r_mean: -136.8 	r_max: -17.8 	r_min: -270.8
#   96 	r_mean: -136.8 	r_max: -17.8 	r_min: -270.8
#   97 	r_mean: -129.2 	r_max: -36.4 	r_min: -270.8
#   98 	r_mean: -129.2 	r_max: -36.4 	r_min: -270.8
#   99 	r_mean: -120.7 	r_max: -36.4 	r_min: -270.8
#  100 	r_mean: -118.1 	r_max: -36.4 	r_min: -270.8
#  101 	r_mean: -118.1 	r_max: -36.4 	r_min: -270.8
#  102 	r_mean: -113.8 	r_max: -55.4 	r_min: -240.8
#  103 	r_mean: -113.8 	r_max: -55.4 	r_min: -240.8
#  104 	r_mean: -114.5 	r_max: -56.7 	r_min: -238.8
#  105 	r_mean: -114.5 	r_max: -56.7 	r_min: -238.8
#  106 	r_mean: -115.7 	r_max: -50.5 	r_min: -238.8
#  107 	r_mean: -115.7 	r_max: -50.5 	r_min: -238.8
#  108 	r_mean: -106.5 	r_max: -36.7 	r_min: -238.8
#  109 	r_mean: -106.5 	r_max: -36.7 	r_min: -238.8
#  110 	r_mean: -101.7 	r_max: -36.7 	r_min: -230.8
#  111 	r_mean: -101.7 	r_max: -36.7 	r_min: -230.8
#  112 	r_mean: -103.6 	r_max: -36.7 	r_min: -235.7
#  113 	r_mean: -103.6 	r_max: -36.7 	r_min: -235.7
#  114 	r_mean: -103.7 	r_max: -36.7 	r_min: -237.7
#  115 	r_mean: -103.7 	r_max: -36.7 	r_min: -237.7
#  116 	r_mean: -109.0 	r_max: -36.7 	r_min: -237.7
#  117 	r_mean: -109.0 	r_max: -36.7 	r_min: -237.7
#  118 	r_mean: -115.2 	r_max: -55.7 	r_min: -237.7
#  119 	r_mean: -115.2 	r_max: -55.7 	r_min: -237.7
#  120 	r_mean: -119.0 	r_max: -55.7 	r_min: -237.7
#  121 	r_mean: -119.0 	r_max: -55.7 	r_min: -237.7
#  122 	r_mean: -119.4 	r_max: -55.7 	r_min: -237.7
#  123 	r_mean: -119.4 	r_max: -55.7 	r_min: -237.7
#  124 	r_mean: -116.0 	r_max: -55.7 	r_min: -234.7
#  125 	r_mean: -112.3 	r_max: -55.7 	r_min: -234.7
#  126 	r_mean: -112.3 	r_max: -55.7 	r_min: -234.7
#  127 	r_mean: -117.0 	r_max: -56.8 	r_min: -234.7
#  128 	r_mean: -117.0 	r_max: -56.8 	r_min: -234.7
#  129 	r_mean: -118.4 	r_max: -56.8 	r_min: -204.7
#  130 	r_mean: -118.4 	r_max: -56.8 	r_min: -204.7
#  131 	r_mean: -115.5 	r_max: -51.8 	r_min: -185.8
#  132 	r_mean: -115.5 	r_max: -51.8 	r_min: -185.8
#  133 	r_mean: -116.9 	r_max: -51.8 	r_min: -224.6
#  134 	r_mean: -116.9 	r_max: -51.8 	r_min: -224.6
#  135 	r_mean: -116.2 	r_max: -51.8 	r_min: -233.7
#  136 	r_mean: -116.2 	r_max: -51.8 	r_min: -233.7
#  137 	r_mean: -113.4 	r_max: -51.8 	r_min: -233.7
#  138 	r_mean: -113.4 	r_max: -51.8 	r_min: -233.7
#  139 	r_mean: -113.5 	r_max: -51.8 	r_min: -233.7
#  140 	r_mean: -113.5 	r_max: -51.8 	r_min: -233.7
#  141 	r_mean: -111.3 	r_max: -52.8 	r_min: -233.7
#  142 	r_mean: -111.3 	r_max: -52.8 	r_min: -233.7
#  143 	r_mean: -109.9 	r_max: -52.8 	r_min: -233.7
#  144 	r_mean: -109.9 	r_max: -52.8 	r_min: -233.7
#  145 	r_mean: -100.3 	r_max: -46.8 	r_min: -225.9
#  146 	r_mean: -100.3 	r_max: -46.8 	r_min: -225.9
#  147 	r_mean: -97.0 	r_max: -46.8 	r_min: -225.9
#  148 	r_mean: -97.0 	r_max: -46.8 	r_min: -225.9
#  149 	r_mean: -93.4 	r_max: -46.8 	r_min: -225.9
#  150 	r_mean: -89.1 	r_max: -46.8 	r_min: -222.2
#  151 	r_mean: -89.1 	r_max: -46.8 	r_min: -222.2
#  152 	r_mean: -87.8 	r_max: -46.8 	r_min: -222.2
#  153 	r_mean: -87.8 	r_max: -46.8 	r_min: -222.2
#  154 	r_mean: -84.5 	r_max: -12.8 	r_min: -222.2
#  155 	r_mean: -84.5 	r_max: -12.8 	r_min: -222.2
#  156 	r_mean: -83.6 	r_max: -12.8 	r_min: -219.8
#  157 	r_mean: -83.6 	r_max: -12.8 	r_min: -219.8
#  158 	r_mean: -80.4 	r_max: -12.8 	r_min: -219.8
#  159 	r_mean: -80.4 	r_max: -12.8 	r_min: -219.8
#  160 	r_mean: -87.4 	r_max: -12.8 	r_min: -219.8
#  161 	r_mean: -87.4 	r_max: -12.8 	r_min: -219.8
#  162 	r_mean: -83.2 	r_max: -12.8 	r_min: -219.8
#  163 	r_mean: -83.2 	r_max: -12.8 	r_min: -219.8
#  164 	r_mean: -90.2 	r_max: -12.8 	r_min: -230.2
#  165 	r_mean: -90.2 	r_max: -12.8 	r_min: -230.2
#  166 	r_mean: -93.4 	r_max: -43.8 	r_min: -230.2
#  167 	r_mean: -93.4 	r_max: -43.8 	r_min: -230.2
#  168 	r_mean: -89.2 	r_max: -43.8 	r_min: -230.2
#  169 	r_mean: -89.2 	r_max: -43.8 	r_min: -230.2
#  170 	r_mean: -82.5 	r_max: -40.7 	r_min: -230.2
#  171 	r_mean: -82.5 	r_max: -40.7 	r_min: -230.2
#  172 	r_mean: -83.9 	r_max: -18.8 	r_min: -230.2
#  173 	r_mean: -83.9 	r_max: -18.8 	r_min: -230.2
#  174 	r_mean: -88.8 	r_max: -18.8 	r_min: -228.7
#  175 	r_mean: -93.7 	r_max: -18.8 	r_min: -239.7
#  176 	r_mean: -93.7 	r_max: -18.8 	r_min: -239.7
#  177 	r_mean: -94.9 	r_max: -18.8 	r_min: -239.7
#  178 	r_mean: -94.9 	r_max: -18.8 	r_min: -239.7
#  179 	r_mean: -102.2 	r_max: -18.8 	r_min: -239.7
#  180 	r_mean: -102.2 	r_max: -18.8 	r_min: -239.7
#  181 	r_mean: -101.9 	r_max: -33.8 	r_min: -239.7
#  182 	r_mean: -101.9 	r_max: -33.8 	r_min: -239.7
#  183 	r_mean: -100.0 	r_max: -33.8 	r_min: -239.7
#  184 	r_mean: -100.0 	r_max: -33.8 	r_min: -239.7
#  185 	r_mean: -95.5 	r_max: -33.8 	r_min: -231.8
#  186 	r_mean: -95.5 	r_max: -33.8 	r_min: -231.8
#  187 	r_mean: -100.8 	r_max: -33.8 	r_min: -231.8
#  188 	r_mean: -100.8 	r_max: -33.8 	r_min: -231.8
#  189 	r_mean: -97.3 	r_max: -33.8 	r_min: -226.2
#  190 	r_mean: -97.3 	r_max: -33.8 	r_min: -226.2
#  191 	r_mean: -99.3 	r_max: -33.8 	r_min: -226.2
#  192 	r_mean: -99.3 	r_max: -33.8 	r_min: -226.2
#  193 	r_mean: -101.3 	r_max: -33.8 	r_min: -226.2
#  194 	r_mean: -101.3 	r_max: -33.8 	r_min: -226.2
#  195 	r_mean: -100.5 	r_max: -28.8 	r_min: -221.2
#  196 	r_mean: -100.5 	r_max: -28.8 	r_min: -221.2
#  197 	r_mean: -100.1 	r_max: -28.8 	r_min: -221.2
#  198 	r_mean: -100.1 	r_max: -28.8 	r_min: -221.2
#  199 	r_mean: -98.7 	r_max: -28.8 	r_min: -221.2
#  200 	r_mean: -93.3 	r_max: -28.8 	r_min: -221.2
#  201 	r_mean: -93.3 	r_max: -28.8 	r_min: -221.2
#  202 	r_mean: -89.9 	r_max: -28.8 	r_min: -221.2
#  203 	r_mean: -89.9 	r_max: -28.8 	r_min: -221.2
#  204 	r_mean: -86.8 	r_max: -38.7 	r_min: -221.2
#  205 	r_mean: -86.8 	r_max: -38.7 	r_min: -221.2
#  206 	r_mean: -83.2 	r_max: -12.8 	r_min: -221.2
#  207 	r_mean: -83.2 	r_max: -12.8 	r_min: -221.2
#  208 	r_mean: -84.2 	r_max: -12.8 	r_min: -221.2
#  209 	r_mean: -84.2 	r_max: -12.8 	r_min: -221.2
#  210 	r_mean: -92.2 	r_max: -12.8 	r_min: -229.4
#  211 	r_mean: -92.2 	r_max: -12.8 	r_min: -229.4
#  212 	r_mean: -94.3 	r_max: -12.8 	r_min: -229.4
#  213 	r_mean: -94.3 	r_max: -12.8 	r_min: -229.4
#  214 	r_mean: -97.3 	r_max: -12.8 	r_min: -229.4
#  215 	r_mean: -97.3 	r_max: -12.8 	r_min: -229.4
#  216 	r_mean: -100.2 	r_max: -34.8 	r_min: -229.4
#  217 	r_mean: -100.2 	r_max: -34.8 	r_min: -229.4
#  218 	r_mean: -100.4 	r_max: -34.8 	r_min: -229.4
#  219 	r_mean: -100.4 	r_max: -34.8 	r_min: -229.4
#  220 	r_mean: -99.0 	r_max: -30.7 	r_min: -233.8
#  221 	r_mean: -99.0 	r_max: -30.7 	r_min: -233.8
#  222 	r_mean: -97.9 	r_max: -23.8 	r_min: -233.8
#  223 	r_mean: -97.9 	r_max: -23.8 	r_min: -233.8
#  224 	r_mean: -97.1 	r_max: -23.8 	r_min: -233.8
#  225 	r_mean: -93.7 	r_max: -23.8 	r_min: -233.8
#  226 	r_mean: -93.7 	r_max: -23.8 	r_min: -233.8
#  227 	r_mean: -92.3 	r_max: -23.8 	r_min: -233.8
#  228 	r_mean: -92.3 	r_max: -23.8 	r_min: -233.8
#  229 	r_mean: -90.6 	r_max: -23.8 	r_min: -202.8
#  230 	r_mean: -90.6 	r_max: -23.8 	r_min: -202.8
#  231 	r_mean: -86.9 	r_max: -23.7 	r_min: -202.8
#  232 	r_mean: -86.9 	r_max: -23.7 	r_min: -202.8
#  233 	r_mean: -84.8 	r_max: -21.7 	r_min: -202.8
#  234 	r_mean: -84.8 	r_max: -21.7 	r_min: -202.8
#  235 	r_mean: -86.8 	r_max: -14.8 	r_min: -202.8
#  236 	r_mean: -86.8 	r_max: -14.8 	r_min: -202.8
#  237 	r_mean: -85.8 	r_max: -14.8 	r_min: -227.8
#  238 	r_mean: -85.8 	r_max: -14.8 	r_min: -227.8
#  239 	r_mean: -84.3 	r_max: -14.8 	r_min: -227.8
#  240 	r_mean: -84.3 	r_max: -14.8 	r_min: -227.8
#  241 	r_mean: -89.0 	r_max: -9.8 	r_min: -227.8
#  242 	r_mean: -89.0 	r_max: -9.8 	r_min: -227.8
#  243 	r_mean: -95.9 	r_max: -9.8 	r_min: -231.7
#  244 	r_mean: -95.9 	r_max: -9.8 	r_min: -231.7
#  245 	r_mean: -94.5 	r_max: -9.8 	r_min: -231.7
#  246 	r_mean: -94.5 	r_max: -9.8 	r_min: -231.7
#  247 	r_mean: -97.8 	r_max: -9.8 	r_min: -231.7
#  248 	r_mean: -97.8 	r_max: -9.8 	r_min: -231.7
#  249 	r_mean: -96.7 	r_max: -9.8 	r_min: -231.7
#  250 	r_mean: -91.8 	r_max: -12.8 	r_min: -231.7
#  251 	r_mean: -91.8 	r_max: -12.8 	r_min: -231.7
#  252 	r_mean: -81.9 	r_max: -10.8 	r_min: -233.7
#  253 	r_mean: -81.9 	r_max: -10.8 	r_min: -233.7
#  254 	r_mean: -78.4 	r_max: -10.8 	r_min: -233.7
#  255 	r_mean: -78.4 	r_max: -10.8 	r_min: -233.7
#  256 	r_mean: -77.5 	r_max: -10.8 	r_min: -233.7
#  257 	r_mean: -77.5 	r_max: -10.8 	r_min: -233.7
#  258 	r_mean: -84.5 	r_max: -10.8 	r_min: -238.8
#  259 	r_mean: -84.5 	r_max: -10.8 	r_min: -238.8
#  260 	r_mean: -88.8 	r_max: -10.8 	r_min: -238.8
#  261 	r_mean: -88.8 	r_max: -10.8 	r_min: -238.8
#  262 	r_mean: -96.4 	r_max: -15.8 	r_min: -238.8
#  263 	r_mean: -96.4 	r_max: -15.8 	r_min: -238.8
#  264 	r_mean: -102.5 	r_max: -15.8 	r_min: -238.8
#  265 	r_mean: -102.5 	r_max: -15.8 	r_min: -238.8
#  266 	r_mean: -103.6 	r_max: -15.8 	r_min: -238.8
#  267 	r_mean: -103.6 	r_max: -15.8 	r_min: -238.8
#  268 	r_mean: -97.8 	r_max: -12.8 	r_min: -236.1
#  269 	r_mean: -97.8 	r_max: -12.8 	r_min: -236.1
#  270 	r_mean: -97.7 	r_max: -12.8 	r_min: -236.1
#  271 	r_mean: -97.7 	r_max: -12.8 	r_min: -236.1
#  272 	r_mean: -97.6 	r_max: -12.8 	r_min: -234.8
#  273 	r_mean: -97.6 	r_max: -12.8 	r_min: -234.8
#  274 	r_mean: -93.5 	r_max: -12.8 	r_min: -234.8
#  275 	r_mean: -98.3 	r_max: -12.8 	r_min: -234.8
#  276 	r_mean: -98.3 	r_max: -12.8 	r_min: -234.8
#  277 	r_mean: -102.0 	r_max: -16.8 	r_min: -234.8
#  278 	r_mean: -102.0 	r_max: -16.8 	r_min: -234.8
#  279 	r_mean: -96.8 	r_max: -18.8 	r_min: -224.8
#  280 	r_mean: -96.8 	r_max: -18.8 	r_min: -224.8
#  281 	r_mean: -88.7 	r_max: -10.8 	r_min: -224.8
#  282 	r_mean: -88.7 	r_max: -10.8 	r_min: -224.8
#  283 	r_mean: -95.5 	r_max: -10.8 	r_min: -224.8
#  284 	r_mean: -95.5 	r_max: -10.8 	r_min: -224.8
#  285 	r_mean: -90.6 	r_max: -10.8 	r_min: -222.2
#  286 	r_mean: -90.6 	r_max: -10.8 	r_min: -222.2
#  287 	r_mean: -90.0 	r_max: -10.8 	r_min: -237.8
#  288 	r_mean: -90.0 	r_max: -10.8 	r_min: -237.8
#  289 	r_mean: -93.9 	r_max: -10.8 	r_min: -237.8
#  290 	r_mean: -93.9 	r_max: -10.8 	r_min: -237.8
#  291 	r_mean: -98.5 	r_max: -9.8 	r_min: -237.8
#  292 	r_mean: -98.5 	r_max: -9.8 	r_min: -237.8
#  293 	r_mean: -92.9 	r_max: -9.8 	r_min: -237.8
#  294 	r_mean: -92.9 	r_max: -9.8 	r_min: -237.8
#  295 	r_mean: -93.0 	r_max: -9.8 	r_min: -237.8
#  296 	r_mean: -93.0 	r_max: -9.8 	r_min: -237.8
#  297 	r_mean: -92.9 	r_max: -9.8 	r_min: -229.8
#  298 	r_mean: -92.9 	r_max: -9.8 	r_min: -229.8
#  299 	r_mean: -91.8 	r_max: -9.8 	r_min: -237.7
#  300 	r_mean: -89.8 	r_max: -11.8 	r_min: -237.7
#  301 	r_mean: -89.8 	r_max: -11.8 	r_min: -237.7
#  302 	r_mean: -92.3 	r_max: -11.8 	r_min: -237.7
#  303 	r_mean: -92.3 	r_max: -11.8 	r_min: -237.7
#  304 	r_mean: -86.8 	r_max: -11.8 	r_min: -237.7
#  305 	r_mean: -86.8 	r_max: -11.8 	r_min: -237.7
#  306 	r_mean: -85.4 	r_max: -14.8 	r_min: -237.7
#  307 	r_mean: -85.4 	r_max: -14.8 	r_min: -237.7
#  308 	r_mean: -87.2 	r_max: -14.8 	r_min: -230.2
#  309 	r_mean: -87.2 	r_max: -14.8 	r_min: -230.2
#  310 	r_mean: -88.9 	r_max: -14.8 	r_min: -230.2
#  311 	r_mean: -88.9 	r_max: -14.8 	r_min: -230.2
#  312 	r_mean: -91.6 	r_max: -14.8 	r_min: -231.3
#  313 	r_mean: -91.6 	r_max: -14.8 	r_min: -231.3
#  314 	r_mean: -88.8 	r_max: -14.8 	r_min: -231.3
#  315 	r_mean: -88.8 	r_max: -14.8 	r_min: -231.3
#  316 	r_mean: -87.2 	r_max: -15.8 	r_min: -231.3
#  317 	r_mean: -87.2 	r_max: -15.8 	r_min: -231.3
#  318 	r_mean: -90.5 	r_max: -15.8 	r_min: -232.7
#  319 	r_mean: -90.5 	r_max: -15.8 	r_min: -232.7
#  320 	r_mean: -92.5 	r_max: -16.8 	r_min: -232.7
#  321 	r_mean: -92.5 	r_max: -16.8 	r_min: -232.7
#  322 	r_mean: -90.1 	r_max: -14.8 	r_min: -232.7
#  323 	r_mean: -90.1 	r_max: -14.8 	r_min: -232.7
#  324 	r_mean: -97.4 	r_max: -14.8 	r_min: -232.7
#  325 	r_mean: -96.4 	r_max: -14.8 	r_min: -232.7
#  326 	r_mean: -96.4 	r_max: -14.8 	r_min: -232.7
#  327 	r_mean: -89.7 	r_max: -14.8 	r_min: -233.7
#  328 	r_mean: -89.7 	r_max: -14.8 	r_min: -233.7
#  329 	r_mean: -88.1 	r_max: -14.7 	r_min: -233.7
#  330 	r_mean: -88.1 	r_max: -14.7 	r_min: -233.7
#  331 	r_mean: -89.2 	r_max: -14.7 	r_min: -233.7
#  332 	r_mean: -89.2 	r_max: -14.7 	r_min: -233.7
#  333 	r_mean: -91.8 	r_max: -14.7 	r_min: -233.7
#  334 	r_mean: -91.8 	r_max: -14.7 	r_min: -233.7
#  335 	r_mean: -98.8 	r_max: -14.7 	r_min: -233.8
#  336 	r_mean: -98.8 	r_max: -14.7 	r_min: -233.8
#  337 	r_mean: -100.9 	r_max: -14.7 	r_min: -233.8
#  338 	r_mean: -100.9 	r_max: -14.7 	r_min: -233.8
#  339 	r_mean: -96.6 	r_max: -10.7 	r_min: -233.8
#  340 	r_mean: -96.6 	r_max: -10.7 	r_min: -233.8
#  341 	r_mean: -95.1 	r_max: -10.7 	r_min: -233.8
#  342 	r_mean: -95.1 	r_max: -10.7 	r_min: -233.8
#  343 	r_mean: -92.6 	r_max: -10.7 	r_min: -233.8
#  344 	r_mean: -92.6 	r_max: -10.7 	r_min: -233.8
#  345 	r_mean: -87.1 	r_max: -10.7 	r_min: -225.7
#  346 	r_mean: -87.1 	r_max: -10.7 	r_min: -225.7
#  347 	r_mean: -92.3 	r_max: -10.7 	r_min: -225.2
#  348 	r_mean: -92.3 	r_max: -10.7 	r_min: -225.2
#  349 	r_mean: -95.3 	r_max: -15.8 	r_min: -225.2
#  350 	r_mean: -93.3 	r_max: -15.8 	r_min: -218.8
#  351 	r_mean: -93.3 	r_max: -15.8 	r_min: -218.8
#  352 	r_mean: -92.9 	r_max: -17.8 	r_min: -218.8
#  353 	r_mean: -92.9 	r_max: -17.8 	r_min: -218.8
#  354 	r_mean: -90.0 	r_max: -15.8 	r_min: -218.8
#  355 	r_mean: -90.0 	r_max: -15.8 	r_min: -218.8
#  356 	r_mean: -86.3 	r_max: -15.8 	r_min: -201.3
#  357 	r_mean: -86.3 	r_max: -15.8 	r_min: -201.3
#  358 	r_mean: -92.5 	r_max: -9.7 	r_min: -236.8
#  359 	r_mean: -92.5 	r_max: -9.7 	r_min: -236.8
#  360 	r_mean: -102.0 	r_max: -9.7 	r_min: -236.8
#  361 	r_mean: -102.0 	r_max: -9.7 	r_min: -236.8
#  362 	r_mean: -96.4 	r_max: -9.7 	r_min: -237.8
#  363 	r_mean: -96.4 	r_max: -9.7 	r_min: -237.8
#  364 	r_mean: -96.5 	r_max: -9.7 	r_min: -237.8
#  365 	r_mean: -96.5 	r_max: -9.7 	r_min: -237.8
#  366 	r_mean: -93.1 	r_max: -9.7 	r_min: -237.8
#  367 	r_mean: -93.1 	r_max: -9.7 	r_min: -237.8
#  368 	r_mean: -91.7 	r_max: -12.8 	r_min: -237.8
#  369 	r_mean: -91.7 	r_max: -12.8 	r_min: -237.8
#  370 	r_mean: -86.7 	r_max: -13.8 	r_min: -237.8
#  371 	r_mean: -86.7 	r_max: -13.8 	r_min: -237.8
#  372 	r_mean: -90.8 	r_max: -13.8 	r_min: -222.8
#  373 	r_mean: -90.8 	r_max: -13.8 	r_min: -222.8
#  374 	r_mean: -94.1 	r_max: -13.8 	r_min: -222.8
#  375 	r_mean: -96.3 	r_max: -14.7 	r_min: -222.8
#  376 	r_mean: -96.3 	r_max: -14.7 	r_min: -222.8
#  377 	r_mean: -93.0 	r_max: -14.7 	r_min: -230.8
#  378 	r_mean: -93.0 	r_max: -14.7 	r_min: -230.8
#  379 	r_mean: -92.4 	r_max: -14.7 	r_min: -230.8
#  380 	r_mean: -92.4 	r_max: -14.7 	r_min: -230.8
#  381 	r_mean: -94.1 	r_max: -14.8 	r_min: -230.8
#  382 	r_mean: -94.1 	r_max: -14.8 	r_min: -230.8
#  383 	r_mean: -92.1 	r_max: -12.8 	r_min: -230.8
#  384 	r_mean: -92.1 	r_max: -12.8 	r_min: -230.8
#  385 	r_mean: -93.6 	r_max: -12.8 	r_min: -230.8
#  386 	r_mean: -93.6 	r_max: -12.8 	r_min: -230.8
#  387 	r_mean: -96.1 	r_max: -12.8 	r_min: -229.2
#  388 	r_mean: -96.1 	r_max: -12.8 	r_min: -229.2
#  389 	r_mean: -94.0 	r_max: -10.7 	r_min: -229.2
#  390 	r_mean: -94.0 	r_max: -10.7 	r_min: -229.2
#  391 	r_mean: -91.8 	r_max: -10.7 	r_min: -229.2
#  392 	r_mean: -91.8 	r_max: -10.7 	r_min: -229.2
#  393 	r_mean: -95.6 	r_max: -10.7 	r_min: -237.8
#  394 	r_mean: -95.6 	r_max: -10.7 	r_min: -237.8
#  395 	r_mean: -98.3 	r_max: -10.7 	r_min: -237.8
#  396 	r_mean: -98.3 	r_max: -10.7 	r_min: -237.8
#  397 	r_mean: -100.2 	r_max: -10.7 	r_min: -237.8
#  398 	r_mean: -100.2 	r_max: -10.7 	r_min: -237.8
#  399 	r_mean: -102.7 	r_max: -13.8 	r_min: -237.8
#  400 	r_mean: -106.6 	r_max: -13.7 	r_min: -237.8
#  401 	r_mean: -106.6 	r_max: -13.7 	r_min: -237.8
#  402 	r_mean: -100.6 	r_max: -11.8 	r_min: -227.8
#  403 	r_mean: -100.6 	r_max: -11.8 	r_min: -227.8
#  404 	r_mean: -94.9 	r_max: -11.8 	r_min: -227.8
#  405 	r_mean: -94.9 	r_max: -11.8 	r_min: -227.8
#  406 	r_mean: -85.2 	r_max: -11.8 	r_min: -227.8
#  407 	r_mean: -85.2 	r_max: -11.8 	r_min: -227.8
#  408 	r_mean: -83.1 	r_max: -11.8 	r_min: -230.8
#  409 	r_mean: -83.1 	r_max: -11.8 	r_min: -230.8
#  410 	r_mean: -80.6 	r_max: -11.8 	r_min: -230.8
#  411 	r_mean: -80.6 	r_max: -11.8 	r_min: -230.8
#  412 	r_mean: -89.4 	r_max: -13.8 	r_min: -230.8
#  413 	r_mean: -89.4 	r_max: -13.8 	r_min: -230.8
#  414 	r_mean: -92.8 	r_max: -13.8 	r_min: -230.8
#  415 	r_mean: -92.8 	r_max: -13.8 	r_min: -230.8
#  416 	r_mean: -95.5 	r_max: -13.8 	r_min: -230.8
#  417 	r_mean: -95.5 	r_max: -13.8 	r_min: -230.8
#  418 	r_mean: -89.8 	r_max: -12.8 	r_min: -229.2
#  419 	r_mean: -89.8 	r_max: -12.8 	r_min: -229.2
#  420 	r_mean: -83.6 	r_max: -12.8 	r_min: -229.2
#  421 	r_mean: -83.6 	r_max: -12.8 	r_min: -229.2
#  422 	r_mean: -80.1 	r_max: -12.8 	r_min: -229.2
#  423 	r_mean: -80.1 	r_max: -12.8 	r_min: -229.2
#  424 	r_mean: -76.4 	r_max: -12.8 	r_min: -229.2
#  425 	r_mean: -73.4 	r_max: -12.8 	r_min: -211.2
#  426 	r_mean: -73.4 	r_max: -12.8 	r_min: -211.2
#  427 	r_mean: -73.2 	r_max: -11.8 	r_min: -211.2
#  428 	r_mean: -73.2 	r_max: -11.8 	r_min: -211.2
#  429 	r_mean: -76.0 	r_max: -11.8 	r_min: -220.2
#  430 	r_mean: -76.0 	r_max: -11.8 	r_min: -220.2
#  431 	r_mean: -72.8 	r_max: -11.8 	r_min: -220.2
#  432 	r_mean: -72.8 	r_max: -11.8 	r_min: -220.2
#  433 	r_mean: -70.6 	r_max: -10.7 	r_min: -220.2
#  434 	r_mean: -70.6 	r_max: -10.7 	r_min: -220.2
#  435 	r_mean: -80.5 	r_max: -10.7 	r_min: -237.8
#  436 	r_mean: -80.5 	r_max: -10.7 	r_min: -237.8
#  437 	r_mean: -82.9 	r_max: -10.7 	r_min: -237.8
#  438 	r_mean: -82.9 	r_max: -10.7 	r_min: -237.8
#  439 	r_mean: -87.4 	r_max: -10.7 	r_min: -237.8
#  440 	r_mean: -87.4 	r_max: -10.7 	r_min: -237.8
#  441 	r_mean: -89.3 	r_max: -10.7 	r_min: -237.8
#  442 	r_mean: -89.3 	r_max: -10.7 	r_min: -237.8
#  443 	r_mean: -89.7 	r_max: -13.8 	r_min: -237.8
#  444 	r_mean: -89.7 	r_max: -13.8 	r_min: -237.8
#  445 	r_mean: -82.7 	r_max: -13.8 	r_min: -225.2
#  446 	r_mean: -82.7 	r_max: -13.8 	r_min: -225.2
#  447 	r_mean: -75.6 	r_max: -9.8 	r_min: -225.2
#  448 	r_mean: -75.6 	r_max: -9.8 	r_min: -225.2
#  449 	r_mean: -66.2 	r_max: -9.8 	r_min: -225.2
#  450 	r_mean: -60.3 	r_max: -9.8 	r_min: -225.2
#  451 	r_mean: -60.3 	r_max: -9.8 	r_min: -225.2
#  452 	r_mean: -58.9 	r_max: -9.8 	r_min: -225.2
# /Supervisor/checkpoint_000452/checkpoint-452
#  453 	r_mean: -58.9 	r_max: -9.8 	r_min: -225.2
#  454 	r_mean: -53.4 	r_max: -9.8 	r_min: -207.8
# /Supervisor/checkpoint_000454/checkpoint-454
#  455 	r_mean: -53.4 	r_max: -9.8 	r_min: -207.8
#  456 	r_mean: -55.4 	r_max: -12.8 	r_min: -207.8
#  457 	r_mean: -55.4 	r_max: -12.8 	r_min: -207.8
#  458 	r_mean: -57.9 	r_max: -12.8 	r_min: -150.8
#  459 	r_mean: -57.9 	r_max: -12.8 	r_min: -150.8
#  460 	r_mean: -63.4 	r_max: -12.8 	r_min: -204.8
#  461 	r_mean: -63.4 	r_max: -12.8 	r_min: -204.8
#  462 	r_mean: -63.7 	r_max: -12.8 	r_min: -208.8
#  463 	r_mean: -63.7 	r_max: -12.8 	r_min: -208.8
#  464 	r_mean: -68.3 	r_max: -12.8 	r_min: -208.8
#  465 	r_mean: -68.3 	r_max: -12.8 	r_min: -208.8
#  466 	r_mean: -72.0 	r_max: -12.8 	r_min: -208.8
#  467 	r_mean: -72.0 	r_max: -12.8 	r_min: -208.8
#  468 	r_mean: -69.9 	r_max: -12.8 	r_min: -208.8
#  469 	r_mean: -69.9 	r_max: -12.8 	r_min: -208.8
#  470 	r_mean: -64.5 	r_max: -12.8 	r_min: -208.8
#  471 	r_mean: -64.5 	r_max: -12.8 	r_min: -208.8
#  472 	r_mean: -62.9 	r_max: -12.8 	r_min: -165.7
#  473 	r_mean: -62.9 	r_max: -12.8 	r_min: -165.7
#  474 	r_mean: -65.8 	r_max: -10.8 	r_min: -216.5
#  475 	r_mean: -67.4 	r_max: -10.8 	r_min: -216.5
#  476 	r_mean: -67.4 	r_max: -10.8 	r_min: -216.5
#  477 	r_mean: -70.1 	r_max: -10.8 	r_min: -216.5
#  478 	r_mean: -70.1 	r_max: -10.8 	r_min: -216.5
#  479 	r_mean: -71.9 	r_max: -10.8 	r_min: -216.5
#  480 	r_mean: -71.9 	r_max: -10.8 	r_min: -216.5
#  481 	r_mean: -74.6 	r_max: -10.8 	r_min: -216.5
#  482 	r_mean: -74.6 	r_max: -10.8 	r_min: -216.5
#  483 	r_mean: -74.4 	r_max: -15.7 	r_min: -214.1
#  484 	r_mean: -74.4 	r_max: -15.7 	r_min: -214.1
#  485 	r_mean: -79.5 	r_max: -15.7 	r_min: -232.8
#  486 	r_mean: -79.5 	r_max: -15.7 	r_min: -232.8
#  487 	r_mean: -80.6 	r_max: -12.8 	r_min: -232.8
#  488 	r_mean: -80.6 	r_max: -12.8 	r_min: -232.8
#  489 	r_mean: -79.5 	r_max: -11.8 	r_min: -232.8
#  490 	r_mean: -79.5 	r_max: -11.8 	r_min: -232.8
#  491 	r_mean: -78.1 	r_max: -11.8 	r_min: -234.8
#  492 	r_mean: -78.1 	r_max: -11.8 	r_min: -234.8
#  493 	r_mean: -77.3 	r_max: -11.8 	r_min: -234.8
#  494 	r_mean: -77.3 	r_max: -11.8 	r_min: -234.8
#  495 	r_mean: -75.2 	r_max: -11.8 	r_min: -234.8
#  496 	r_mean: -75.2 	r_max: -11.8 	r_min: -234.8
#  497 	r_mean: -76.0 	r_max: -11.8 	r_min: -234.8
#  498 	r_mean: -76.0 	r_max: -11.8 	r_min: -234.8
#  499 	r_mean: -74.8 	r_max: -12.7 	r_min: -234.8
#  500 	r_mean: -75.5 	r_max: -12.7 	r_min: -227.8
# '/Supervisor/checkpoint_000500/checkpoint-500'

# %%
for i in range(int(100)):
    results_dict=trainer.train()
    print_results(results_dict)
    if m < results_dict["episode_reward_mean"]:
        print(trainer.save("/Supervisor"))
        m = results_dict["episode_reward_mean"]
# Out:
#  601 	r_mean: -70.8 	r_max: -12.8 	r_min: -222.8
#  602 	r_mean: -66.9 	r_max: -10.8 	r_min: -222.8
#  603 	r_mean: -66.9 	r_max: -10.8 	r_min: -222.8
#  604 	r_mean: -64.1 	r_max: -10.8 	r_min: -222.8
#  605 	r_mean: -64.1 	r_max: -10.8 	r_min: -222.8
#  606 	r_mean: -65.9 	r_max: -10.8 	r_min: -234.8
#  607 	r_mean: -65.9 	r_max: -10.8 	r_min: -234.8
#  608 	r_mean: -71.2 	r_max: -10.8 	r_min: -237.8
#  609 	r_mean: -71.2 	r_max: -10.8 	r_min: -237.8
#  610 	r_mean: -81.1 	r_max: -10.8 	r_min: -237.8
#  611 	r_mean: -81.1 	r_max: -10.8 	r_min: -237.8
#  612 	r_mean: -83.8 	r_max: -13.8 	r_min: -237.8
#  613 	r_mean: -83.8 	r_max: -13.8 	r_min: -237.8
#  614 	r_mean: -88.0 	r_max: -12.7 	r_min: -237.8
#  615 	r_mean: -88.0 	r_max: -12.7 	r_min: -237.8
#  616 	r_mean: -86.0 	r_max: -12.7 	r_min: -237.8
#  617 	r_mean: -86.0 	r_max: -12.7 	r_min: -237.8
#  618 	r_mean: -85.4 	r_max: -12.7 	r_min: -235.7
#  619 	r_mean: -85.4 	r_max: -12.7 	r_min: -235.7
#  620 	r_mean: -77.7 	r_max: -12.7 	r_min: -235.7
#  621 	r_mean: -77.7 	r_max: -12.7 	r_min: -235.7
#  622 	r_mean: -74.7 	r_max: -12.7 	r_min: -235.7
#  623 	r_mean: -74.7 	r_max: -12.7 	r_min: -235.7
#  624 	r_mean: -65.0 	r_max: -12.8 	r_min: -235.7
#  625 	r_mean: -62.5 	r_max: -13.7 	r_min: -235.7
#  626 	r_mean: -62.5 	r_max: -13.7 	r_min: -235.7
#  627 	r_mean: -51.5 	r_max: -12.7 	r_min: -230.8
#  628 	r_mean: -51.5 	r_max: -12.7 	r_min: -230.8
#  629 	r_mean: -47.7 	r_max: -11.7 	r_min: -221.8
# /Supervisor/checkpoint_000629/checkpoint-629
#  630 	r_mean: -47.7 	r_max: -11.7 	r_min: -221.8
#  631 	r_mean: -42.8 	r_max: -11.7 	r_min: -150.7
# /Supervisor/checkpoint_000631/checkpoint-631
#  632 	r_mean: -42.8 	r_max: -11.7 	r_min: -150.7
#  633 	r_mean: -43.4 	r_max: -11.7 	r_min: -150.7
#  634 	r_mean: -43.4 	r_max: -11.7 	r_min: -150.7
#  635 	r_mean: -42.5 	r_max: -11.7 	r_min: -150.7
# /Supervisor/checkpoint_000635/checkpoint-635
#  636 	r_mean: -42.5 	r_max: -11.7 	r_min: -150.7
#  637 	r_mean: -44.2 	r_max: -11.7 	r_min: -151.7
#  638 	r_mean: -44.2 	r_max: -11.7 	r_min: -151.7
#  639 	r_mean: -41.6 	r_max: -12.7 	r_min: -151.7
# /Supervisor/checkpoint_000639/checkpoint-639
#  640 	r_mean: -41.6 	r_max: -12.7 	r_min: -151.7
#  641 	r_mean: -44.4 	r_max: -11.8 	r_min: -151.7
#  642 	r_mean: -44.4 	r_max: -11.8 	r_min: -151.7
#  643 	r_mean: -45.1 	r_max: -11.8 	r_min: -151.7
#  644 	r_mean: -45.1 	r_max: -11.8 	r_min: -151.7
#  645 	r_mean: -45.4 	r_max: -10.8 	r_min: -151.7
#  646 	r_mean: -45.4 	r_max: -10.8 	r_min: -151.7
#  647 	r_mean: -46.3 	r_max: -10.8 	r_min: -128.8
#  648 	r_mean: -46.3 	r_max: -10.8 	r_min: -128.8
#  649 	r_mean: -51.3 	r_max: -10.8 	r_min: -201.8
#  650 	r_mean: -48.3 	r_max: -10.8 	r_min: -201.8
#  651 	r_mean: -48.3 	r_max: -10.8 	r_min: -201.8
#  652 	r_mean: -45.4 	r_max: -10.8 	r_min: -201.8
#  653 	r_mean: -45.4 	r_max: -10.8 	r_min: -201.8
#  654 	r_mean: -48.5 	r_max: -12.8 	r_min: -219.8
#  655 	r_mean: -48.5 	r_max: -12.8 	r_min: -219.8
#  656 	r_mean: -47.2 	r_max: -11.8 	r_min: -219.8
#  657 	r_mean: -47.2 	r_max: -11.8 	r_min: -219.8
#  658 	r_mean: -44.1 	r_max: -11.8 	r_min: -219.8
#  659 	r_mean: -44.1 	r_max: -11.8 	r_min: -219.8
#  660 	r_mean: -45.5 	r_max: -11.8 	r_min: -219.8
#  661 	r_mean: -45.5 	r_max: -11.8 	r_min: -219.8
#  662 	r_mean: -51.4 	r_max: -11.8 	r_min: -219.8
#  663 	r_mean: -51.4 	r_max: -11.8 	r_min: -219.8
#  664 	r_mean: -53.3 	r_max: -11.8 	r_min: -230.8
#  665 	r_mean: -53.3 	r_max: -11.8 	r_min: -230.8
#  666 	r_mean: -56.7 	r_max: -11.2 	r_min: -230.8
#  667 	r_mean: -56.7 	r_max: -11.2 	r_min: -230.8
#  668 	r_mean: -58.5 	r_max: -11.2 	r_min: -230.8
#  669 	r_mean: -58.5 	r_max: -11.2 	r_min: -230.8
#  670 	r_mean: -56.5 	r_max: -11.2 	r_min: -230.8
#  671 	r_mean: -56.5 	r_max: -11.2 	r_min: -230.8
#  672 	r_mean: -52.2 	r_max: -11.2 	r_min: -230.8
#  673 	r_mean: -52.2 	r_max: -11.2 	r_min: -230.8
#  674 	r_mean: -54.1 	r_max: -11.2 	r_min: -214.8
#  675 	r_mean: -57.3 	r_max: -11.8 	r_min: -201.8
#  676 	r_mean: -57.3 	r_max: -11.8 	r_min: -201.8
#  677 	r_mean: -53.8 	r_max: -10.8 	r_min: -189.7
#  678 	r_mean: -53.8 	r_max: -10.8 	r_min: -189.7
#  679 	r_mean: -56.1 	r_max: -10.8 	r_min: -189.7
#  680 	r_mean: -56.1 	r_max: -10.8 	r_min: -189.7
#  681 	r_mean: -58.4 	r_max: -10.8 	r_min: -201.7
#  682 	r_mean: -58.4 	r_max: -10.8 	r_min: -201.7
#  683 	r_mean: -51.8 	r_max: -10.8 	r_min: -201.7
#  684 	r_mean: -51.8 	r_max: -10.8 	r_min: -201.7
#  685 	r_mean: -47.7 	r_max: -10.8 	r_min: -201.7
#  686 	r_mean: -47.7 	r_max: -10.8 	r_min: -201.7
#  687 	r_mean: -48.2 	r_max: -10.8 	r_min: -201.7
#  688 	r_mean: -48.2 	r_max: -10.8 	r_min: -201.7
#  689 	r_mean: -45.9 	r_max: -12.8 	r_min: -201.7
#  690 	r_mean: -45.9 	r_max: -12.8 	r_min: -201.7
#  691 	r_mean: -46.7 	r_max: -13.8 	r_min: -144.8
#  692 	r_mean: -46.7 	r_max: -13.8 	r_min: -144.8
#  693 	r_mean: -47.5 	r_max: -13.8 	r_min: -149.8
#  694 	r_mean: -47.5 	r_max: -13.8 	r_min: -149.8
#  695 	r_mean: -44.8 	r_max: -12.8 	r_min: -149.8
#  696 	r_mean: -44.8 	r_max: -12.8 	r_min: -149.8
#  697 	r_mean: -43.8 	r_max: -12.7 	r_min: -149.8
#  698 	r_mean: -43.8 	r_max: -12.7 	r_min: -149.8
#  699 	r_mean: -47.5 	r_max: -12.7 	r_min: -179.8
#  700 	r_mean: -45.7 	r_max: -12.7 	r_min: -237.8

# %%
import time
t = time.time()
for i in range(100):
    loaded_trainer.compute_single_action(np.ones(52))[2]['q_values']
print(time.time() - t)

# %%
p = loaded_trainer.get_policy()
p.model.forward({'obs_flat':np.ones((1,52))}, np.ones((1,52)), None)

# %%
import time
t = time.time()
for i in range(100):
    loaded_trainer.compute_single_action(np.ones(52), full_fetch=True)[2]['q_values']
print(time.time() - t)
